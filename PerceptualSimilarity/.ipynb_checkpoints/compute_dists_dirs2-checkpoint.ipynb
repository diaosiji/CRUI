# %% [markdown]
# # 计算距离
#
# 先对compute_dists_dirs.py脚本进行修改，使之能够在jupyter下运行起来。

# %%
import argparse
import os
import models
from util import util

#parser = argparse.ArgumentParser(formatter_class=argparse.ArgumentDefaultsHelpFormatter)
#parser.add_argument('-d0','--dir0', type=str, default='./imgs/ex_dir0')
#parser.add_argument('-d1','--dir1', type=str, default='./imgs/ex_dir1')
#parser.add_argument('-o','--out', type=str, default='./imgs/example_dists.txt')
#parser.add_argument('--use_gpu', action='store_true', help='turn on flag to use GPU')

#opt = parser.parse_args()

dir0 = './imgs/ex_dir0'
dir1 = './imgs/ex_dir1'
out = './imgs/example_dists.txt'
use_gpu = False


## Initializing the model
model = models.PerceptualLoss(model='net-lin',net='alex',use_gpu=use_gpu)

# crawl directories
f = open(out,'w')
files = os.listdir(dir0)

for file in files:
    
	if(os.path.exists(os.path.join(dir1,file))):
		# Load images
		img0 = util.im2tensor(util.load_image(os.path.join(dir0,file))) # RGB image from [-1,1]
		img1 = util.im2tensor(util.load_image(os.path.join(dir1,file)))

		if(use_gpu):
			img0 = img0.cuda()
			img1 = img1.cuda()

		# Compute distance
		dist01 = model.forward(img0,img1)
		print('%s: %.3f'%(file,dist01))
		f.writelines('%s: %.6f\n'%(file,dist01))

f.close()
# Out:
# Setting up Perceptual loss...
# Loading model from: /Users/diaosiji/PerceptualSimilarity/models/weights/v0.1/alex.pth
# ...[net-lin [alex]] initialized
# ...Done

# %% [markdown]
# ## 修改目标
#
# - 增加一个路径参数dir2。这样可以dir0放原图（鞋子+logo），dir1放生成图（鞋子+logo的轮廓图经pix2pix输出的生成图），dir2放添加生成图（无logo鞋子轮廓经pix2pix输出的生成图+logo）；
# - 在在dir0的遍历循环中，增加一个代码段，用于判断dir2中是否存在同名文件，如果是，则同样进行比对，计算dir2中图片与原图的距离；
# - 计算出来的距离数据应该放到Nx2的张量中，便于比较计算均值，方差等；
#
# ### 导入依赖

# %%
import argparse
import os
import models
from util import util

# for compute
import numpy as np
import torch

# %% [markdown]
# ### 设置参数

# %%
# ex_dir0用于放置物体加logo原图
dir0 = './imgs/ex_dir0'

# ex_dir1用于放置cGAN直接生成图
dir1 = './imgs/ex_dir1'

# ex_dir2用于放置生成添加logo图
dir2 = './imgs/ex_dir2'

# ex_dir3用于发放至物体加logo图的轮廓提取图
dir3 = './imgs/ex_dir3'

# 输出计算结果的文件路径
out = './imgs/example_dists.txt'

# 是否使用GPU
use_gpu = False

# %% [markdown]
# ### 初始化模型及记录文件

# %%
## Initializing the model
model = models.PerceptualLoss(model='net-lin',net='alex',use_gpu=use_gpu)

# crawl directories 不需要这个文件
#f = open(out,'w')
# Out:
# Setting up Perceptual loss...
# Loading model from: /Users/diaosiji/PerceptualSimilarity/models/weights/v0.1/alex.pth
# ...[net-lin [alex]] initialized
# ...Done

# %% [markdown]
# ### 主循环
#
# - 修改1：取消文件写入，直接在笔记内计算即可；OK
# - 修改2：添加一个新的目录dir2；OK
#
# - 注意：dir1、2、3内的图片命名和后缀都要一致，如果是jpg和png就不行。可以用mac批量替换后缀！
#
# 模型输出的dist0x距离是torch.Tensor数据类型。

# %%
# 遍历原图文件夹内图片
files = os.listdir(dir0)
# 列表
dist01_list = []
dist02_list = []
dist03_list = []

for file in files:
    img0 = util.im2tensor(util.load_image(os.path.join(dir0,file))) # RGB image from [-1,1]
    # 这是在生成图目录
    #print(os.path.exists(os.path.join(dir1,file)))
    if(os.path.exists(os.path.join(dir1,file))):
        # Load images
        img1 = util.im2tensor(util.load_image(os.path.join(dir1,file)))
        #print(img1)

    # 这是在添加生成图目录
    #print(os.path.exists(os.path.join(dir2,file)))
    if(os.path.exists(os.path.join(dir2,file))):
        # Load images
        img2 = util.im2tensor(util.load_image(os.path.join(dir2,file)))
        
    # 这是在有logo原图的轮廓图的目录
    if(os.path.exists(os.path.join(dir3,file))):
        # Load images
        img3 = util.im2tensor(util.load_image(os.path.join(dir3,file)))

        if(use_gpu):
            img0 = img0.cuda()
            img1 = img1.cuda()
            img2 = img2.cuda()
            img3 = img3.cuda()

        # Compute distance
        # 原图和生成图距离
        dist01 = model.forward(img0,img1)
        #print(dist01.data.numpy()[0,0,0,0])
        dist01_list.append(dist01.data.numpy()[0,0,0,0])
        
        # 原图和添加生成图距离
        dist02 = model.forward(img0,img2)
        dist02_list.append(dist02.data.numpy()[0,0,0,0])
        
        # 原图和轮廓图距离
        dist03 = model.forward(img0,img3)
        dist03_list.append(dist03.data.numpy()[0,0,0,0])
        
        print('%s cGAN: %.3f augment: %.3f sketch: %.3f'%(file,dist01,dist02,dist03))
       
#print(dist01_list)
#print(dist02_list)
tensor1 = torch.Tensor(dist01_list)
tensor2 = torch.Tensor(dist02_list)
tensor3 = torch.Tensor(dist03_list)

print('cGAN mean distance with origin:', tensor1.mean())
print('cGAN distance std with origin:', tensor1.std())
print('augment mean distance with origin:', tensor2.mean())
print('augment distance std with origin:', tensor2.std())
print('sketch mean distance with origin:', tensor3.mean())
print('sketch distance std with origin:', tensor3.std())
# Out:
# 189.jpg cGAN: 0.318 augment: 0.121
# 162.jpg cGAN: 0.369 augment: 0.209
# 176.jpg cGAN: 0.405 augment: 0.253
# 200.jpg cGAN: 0.254 augment: 0.064
# 016.jpg cGAN: 0.252 augment: 0.124
# 002.jpg cGAN: 0.286 augment: 0.149
# 003.jpg cGAN: 0.190 augment: 0.058
# 017.jpg cGAN: 0.242 augment: 0.097
# 177.jpg cGAN: 0.336 augment: 0.164
# 163.jpg cGAN: 0.387 augment: 0.225
# 188.jpg cGAN: 0.319 augment: 0.165
# 149.jpg cGAN: 0.280 augment: 0.111
# 175.jpg cGAN: 0.328 augment: 0.403
# 161.jpg cGAN: 0.272 augment: 0.136
# 029.jpg cGAN: 0.342 augment: 0.272
# 001.jpg cGAN: 0.344 augment: 0.174
# 015.jpg cGAN: 0.243 augment: 0.093
# 014.jpg cGAN: 0.325 augment: 0.082
# 028.jpg cGAN: 0.317 augment: 0.111
# 160.jpg cGAN: 0.267 augment: 0.128
# 174.jpg cGAN: 0.183 augment: 0.067
# 148.jpg cGAN: 0.289 augment: 0.169
# 170.jpg cGAN: 0.350 augment: 0.197
# 164.jpg cGAN: 0.336 augment: 0.194
# 158.jpg cGAN: 0.356 augment: 0.236
# 004.jpg cGAN: 0.394 augment: 0.210
# 010.jpg cGAN: 0.303 augment: 0.134
# 038.jpg cGAN: 0.271 augment: 0.098
# 039.jpg cGAN: 0.268 augment: 0.205
# 011.jpg cGAN: 0.203 augment: 0.084
# 005.jpg cGAN: 0.278 augment: 0.154
# 159.jpg cGAN: 0.282 augment: 0.092
# 165.jpg cGAN: 0.323 augment: 0.123
# 171.jpg cGAN: 0.291 augment: 0.119
# 198.jpg cGAN: 0.348 augment: 0.153
# 167.jpg cGAN: 0.270 augment: 0.134
# 173.jpg cGAN: 0.364 augment: 0.111
# 013.jpg cGAN: 0.347 augment: 0.141
# 007.jpg cGAN: 0.290 augment: 0.137
# 006.jpg cGAN: 0.303 augment: 0.100
# 012.jpg cGAN: 0.303 augment: 0.100
# 172.jpg cGAN: 0.309 augment: 0.152
# 166.jpg cGAN: 0.244 augment: 0.113
# 199.jpg cGAN: 0.322 augment: 0.188
# 129.jpg cGAN: 0.250 augment: 0.094
# 101.jpg cGAN: 0.260 augment: 0.109
# 115.jpg cGAN: 0.296 augment: 0.102
# 049.jpg cGAN: 0.370 augment: 0.201
# 075.jpg cGAN: 0.208 augment: 0.096
# 061.jpg cGAN: 0.310 augment: 0.176
# 060.jpg cGAN: 0.315 augment: 0.231
# 074.jpg cGAN: 0.331 augment: 0.218
# 048.jpg cGAN: 0.236 augment: 0.142
# 114.jpg cGAN: 0.323 augment: 0.217
# 100.jpg cGAN: 0.427 augment: 0.233
# 128.jpg cGAN: 0.339 augment: 0.165
# 116.jpg cGAN: 0.205 augment: 0.096
# 102.jpg cGAN: 0.265 augment: 0.075
# 089.jpg cGAN: 0.242 augment: 0.110
# 062.jpg cGAN: 0.247 augment: 0.087
# 076.jpg cGAN: 0.357 augment: 0.192
# 077.jpg cGAN: 0.290 augment: 0.117
# 063.jpg cGAN: 0.266 augment: 0.061
# 088.jpg cGAN: 0.339 augment: 0.197
# 103.jpg cGAN: 0.481 augment: 0.198
# 117.jpg cGAN: 0.236 augment: 0.031
# 113.jpg cGAN: 0.266 augment: 0.099
# 107.jpg cGAN: 0.312 augment: 0.160
# 098.jpg cGAN: 0.264 augment: 0.077
# 067.jpg cGAN: 0.229 augment: 0.067
# 073.jpg cGAN: 0.318 augment: 0.162
# 072.jpg cGAN: 0.290 augment: 0.088
# 066.jpg cGAN: 0.232 augment: 0.075
# 099.jpg cGAN: 0.253 augment: 0.127
# 106.jpg cGAN: 0.316 augment: 0.130
# 112.jpg cGAN: 0.421 augment: 0.108
# 104.jpg cGAN: 0.351 augment: 0.078
# 110.jpg cGAN: 0.294 augment: 0.086
# 138.jpg cGAN: 0.260 augment: 0.164
# 070.jpg cGAN: 0.313 augment: 0.083
# 064.jpg cGAN: 0.311 augment: 0.112
# 058.jpg cGAN: 0.169 augment: 0.079
# 059.jpg cGAN: 0.301 augment: 0.066
# 065.jpg cGAN: 0.364 augment: 0.261
# 071.jpg cGAN: 0.311 augment: 0.140
# 139.jpg cGAN: 0.207 augment: 0.157
# 111.jpg cGAN: 0.326 augment: 0.128
# 105.jpg cGAN: 0.204 augment: 0.085
# 108.jpg cGAN: 0.348 augment: 0.187
# 120.jpg cGAN: 0.237 augment: 0.041
# 134.jpg cGAN: 0.300 augment: 0.136
# 097.jpg cGAN: 0.380 augment: 0.145
# 083.jpg cGAN: 0.219 augment: 0.064
# 068.jpg cGAN: 0.236 augment: 0.096
# 054.jpg cGAN: 0.263 augment: 0.065
# 040.jpg cGAN: 0.315 augment: 0.090
# 041.jpg cGAN: 0.286 augment: 0.063
# 055.jpg cGAN: 0.274 augment: 0.120
# 069.jpg cGAN: 0.328 augment: 0.170
# 082.jpg cGAN: 0.268 augment: 0.107
# 096.jpg cGAN: 0.384 augment: 0.159
# 135.jpg cGAN: 0.331 augment: 0.129
# 121.jpg cGAN: 0.358 augment: 0.142
# 109.jpg cGAN: 0.251 augment: 0.104
# 137.jpg cGAN: 0.330 augment: 0.142
# 123.jpg cGAN: 0.237 augment: 0.175
# 080.jpg cGAN: 0.276 augment: 0.061
# 094.jpg cGAN: 0.215 augment: 0.037
# 043.jpg cGAN: 0.258 augment: 0.121
# 057.jpg cGAN: 0.261 augment: 0.162
# 056.jpg cGAN: 0.303 augment: 0.140
# 042.jpg cGAN: 0.250 augment: 0.084
# 095.jpg cGAN: 0.266 augment: 0.111
# 081.jpg cGAN: 0.271 augment: 0.151
# 122.jpg cGAN: 0.219 augment: 0.067
# 136.jpg cGAN: 0.324 augment: 0.198
# 132.jpg cGAN: 0.245 augment: 0.066
# 126.jpg cGAN: 0.269 augment: 0.103
# 085.jpg cGAN: 0.346 augment: 0.232
# 091.jpg cGAN: 0.331 augment: 0.183
# 046.jpg cGAN: 0.229 augment: 0.081
# 052.jpg cGAN: 0.347 augment: 0.121
# 053.jpg cGAN: 0.393 augment: 0.191
# 047.jpg cGAN: 0.311 augment: 0.249
# 090.jpg cGAN: 0.255 augment: 0.182
# 084.jpg cGAN: 0.441 augment: 0.299
# 127.jpg cGAN: 0.291 augment: 0.156
# 133.jpg cGAN: 0.319 augment: 0.192
# 125.jpg cGAN: 0.368 augment: 0.173
# 131.jpg cGAN: 0.319 augment: 0.183
# 119.jpg cGAN: 0.329 augment: 0.150
# 092.jpg cGAN: 0.335 augment: 0.265
# 086.jpg cGAN: 0.289 augment: 0.164
# 051.jpg cGAN: 0.479 augment: 0.135
# 045.jpg cGAN: 0.341 augment: 0.165
# 079.jpg cGAN: 0.372 augment: 0.342
# 078.jpg cGAN: 0.337 augment: 0.252
# 044.jpg cGAN: 0.235 augment: 0.102
# 050.jpg cGAN: 0.279 augment: 0.165
# 087.jpg cGAN: 0.300 augment: 0.069
# 093.jpg cGAN: 0.351 augment: 0.183
# 118.jpg cGAN: 0.247 augment: 0.178
# 130.jpg cGAN: 0.263 augment: 0.125
# 124.jpg cGAN: 0.376 augment: 0.215
# 180.jpg cGAN: 0.392 augment: 0.132
# 194.jpg cGAN: 0.335 augment: 0.053
# 143.jpg cGAN: 0.282 augment: 0.148
# 157.jpg cGAN: 0.261 augment: 0.040
# 037.jpg cGAN: 0.196 augment: 0.042
# 023.jpg cGAN: 0.344 augment: 0.219
# 022.jpg cGAN: 0.219 augment: 0.088
# 036.jpg cGAN: 0.408 augment: 0.203
# 156.jpg cGAN: 0.241 augment: 0.073
# 142.jpg cGAN: 0.231 augment: 0.089
# 195.jpg cGAN: 0.229 augment: 0.030
# 181.jpg cGAN: 0.244 augment: 0.084
# 197.jpg cGAN: 0.216 augment: 0.015
# 183.jpg cGAN: 0.210 augment: 0.081
# 168.jpg cGAN: 0.227 augment: 0.117
# 154.jpg cGAN: 0.395 augment: 0.179
# 140.jpg cGAN: 0.261 augment: 0.075
# 008.jpg cGAN: 0.258 augment: 0.167
# 020.jpg cGAN: 0.249 augment: 0.092
# 034.jpg cGAN: 0.281 augment: 0.098
# 035.jpg cGAN: 0.292 augment: 0.118
# 021.jpg cGAN: 0.340 augment: 0.114
# 009.jpg cGAN: 0.275 augment: 0.096
# 141.jpg cGAN: 0.383 augment: 0.275
# 155.jpg cGAN: 0.327 augment: 0.140
# 169.jpg cGAN: 0.281 augment: 0.127
# 182.jpg cGAN: 0.332 augment: 0.089
# 196.jpg cGAN: 0.253 augment: 0.109
# 192.jpg cGAN: 0.308 augment: 0.119
# 186.jpg cGAN: 0.223 augment: 0.070
# 151.jpg cGAN: 0.259 augment: 0.183
# 145.jpg cGAN: 0.308 augment: 0.091
# 179.jpg cGAN: 0.264 augment: 0.068
# 025.jpg cGAN: 0.408 augment: 0.218
# 031.jpg cGAN: 0.389 augment: 0.058
# 019.jpg cGAN: 0.463 augment: 0.320
# 018.jpg cGAN: 0.225 augment: 0.099
# 030.jpg cGAN: 0.256 augment: 0.114
# 024.jpg cGAN: 0.377 augment: 0.193
# 178.jpg cGAN: 0.437 augment: 0.188
# 144.jpg cGAN: 0.242 augment: 0.061
# 150.jpg cGAN: 0.279 augment: 0.132
# 187.jpg cGAN: 0.266 augment: 0.159
# 193.jpg cGAN: 0.310 augment: 0.235
# 185.jpg cGAN: 0.248 augment: 0.110
# 191.jpg cGAN: 0.278 augment: 0.101
# 146.jpg cGAN: 0.316 augment: 0.072
# 152.jpg cGAN: 0.271 augment: 0.089
# 032.jpg cGAN: 0.233 augment: 0.276
# 026.jpg cGAN: 0.453 augment: 0.154
# 027.jpg cGAN: 0.239 augment: 0.119
# 033.jpg cGAN: 0.252 augment: 0.059
# 153.jpg cGAN: 0.293 augment: 0.108
# 147.jpg cGAN: 0.282 augment: 0.181
# 190.jpg cGAN: 0.264 augment: 0.096
# 184.jpg cGAN: 0.253 augment: 0.122
# cGAN mean distance with origin: tensor(0.2978)
# cGAN distance std with origin: tensor(0.0596)
# augment mean distance with origin: tensor(0.1365)
# augment distance std with origin: tensor(0.0628)
